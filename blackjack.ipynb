# %% [markdown]
# El juego va a funcionar dando dos cartas random de un mazo de 52 cartas con una tupla. De ahi el codigo analiza si las cartas que obtuviste dan 21,
# si es asi ganas. Si tienes menos puedes borrow hasta tener 21, pero si te pasas pierdes.
# Yo creo que para hacerlo primero tiene que definir los valore de cada carta, luego ponerlos en una lista con todas las cartas.
#
# After I import random so that I can take out two cards, afetr it analices the cards. If it has less than 21 in points from cards, the user is asked if they want to borrow. The borrrow thing is made by an if statement. I want also to use while, is, elif, else, tuple, equal or ==.
# for getting the 54cards i will use the tuplet list and multiply by four (each list has the unique value of the card once for each). The shufflle can also be done with random.
#
# The reason for using a tuple its because in a tuple you cannot make changes. In a list you can but in a tuple you cannot. That is why in this case I would use a tuple because we do not want the cards to change, just to use them in order to win the game. For now I want the dealer to be the machine, howveer when more students are involved I can make it so that they take that role.

# %% [markdown]
# | Function Name     | Description                                                     | Input Parameters                | Return Value                |
# |-------------------|-----------------------------------------------------------------|--------------------------------|-----------------------------|
# | card_lists()      | Creates the 52-card deck using a tuple                          | none                           | tuple (the deck)           |
# | check_points()    | Calculates and returns the total points of a hand               | list of cards so  list[int]      | int (total points)         |
# | check_game()      | Decides if the player wins, loses, or continues                 | int (points)                   | string (game state)        |
# | borrow()          | Lets the player draw new cards until they stop or game ends     | tuple deck, int points         | int (updated points)       |
# |player_hand()| has the value that the player has right now, can change| list of current cards so list(cards)| Lets the player play the cards they have, it changes. |In and out of list|
